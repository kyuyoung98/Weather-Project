# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %%
df = pd.read_csv("./files/korea_weather/20230918_Weather.csv")

# %%
df.head()
# Out:
#    City ID   City Name       Lon      Lat  Weather ID Weather Main  \
# 0  1832008  Tokusan-ri  128.7000  35.1333         800        Clear
# 1  1832015    Heunghae  129.3522  36.1125         802       Clouds
# 2  1832157      Reisui  127.7378  34.7442         800        Clear
# 3  1832215      Yeonil  129.3450  35.9942         800        Clear
# 4  1832257     Neietsu  128.4682  37.1845         800        Clear
#
#    Temperature (K)  Humidity (%)  Visibility (m)  Wind Speed (m/s)  \
# 0           298.14            85           10000              1.46
# 1           297.20            86           10000              2.07
# 2           297.43            84           10000              3.53
# 3           296.93            87           10000              2.08
# 4           294.21            97           10000              0.55
#
#    Clouds (%)          Date (Unix)         Timezone (s)
# 0           3  2023-09-18 10:53:35  2023-09-18 19:53:35
# ...

# %%
# 칼럼명 변환
df = df.rename(columns={
    'City ID': 'weather_id',
    'City Name': 'city_name',
    'Lon': 'lon',
    'Lat': 'lat',
    'Weather Main': 'weather_main',
    'Temperature (K)': 'temperature',
    'Humidity (%)': 'humidity',
    'Wind Speed (m/s)': 'wind_speed',
    'Clouds (%)': 'clouds',
    'Date (Unix)': 'date'
})

# %%
# 필요한 열만 선택
selected_columns = ['weather_id', 'date', 'city_name', 'lon', 'lat', 'weather_main', 'temperature', 'humidity', 'wind_speed', 'clouds']
df = df[selected_columns]

# %%
df.head()
# Out:
#    weather_id                 date   city_name       lon      lat  \
# 0     1832008  2023-09-18 10:53:35  Tokusan-ri  128.7000  35.1333
# 1     1832015  2023-09-18 10:57:41    Heunghae  129.3522  36.1125
# 2     1832157  2023-09-18 10:57:42      Reisui  127.7378  34.7442
# 3     1832215  2023-09-18 10:54:27      Yeonil  129.3450  35.9942
# 4     1832257  2023-09-18 10:55:36     Neietsu  128.4682  37.1845
#
#   weather_main  temperature  humidity  wind_speed  clouds
# 0        Clear       298.14        85        1.46       3
# 1       Clouds       297.20        86        2.07      30
# 2        Clear       297.43        84        3.53       0
# 3        Clear       296.93        87        2.08       4
# 4        Clear       294.21        97        0.55      10

# %%
# 'date' 열을 날짜 형식으로 파싱
df['date'] = pd.to_datetime(df['date'])

# 'date' 열을 'YYYY-MM-DD' 형식으로 변환
df['date'] = df['date'].dt.strftime('%Y-%m-%d')

# %%
df.head()
# Out:
#    weather_id        date   city_name       lon      lat weather_main  \
# 0     1832008  2023-09-18  Tokusan-ri  128.7000  35.1333        Clear
# 1     1832015  2023-09-18    Heunghae  129.3522  36.1125       Clouds
# 2     1832157  2023-09-18      Reisui  127.7378  34.7442        Clear
# 3     1832215  2023-09-18      Yeonil  129.3450  35.9942        Clear
# 4     1832257  2023-09-18     Neietsu  128.4682  37.1845        Clear
#
#    temperature  humidity  wind_speed  clouds
# 0       298.14        85        1.46       3
# 1       297.20        86        2.07      30
# 2       297.43        84        3.53       0
# 3       296.93        87        2.08       4
# 4       294.21        97        0.55      10

# %%
# DB 설정
from sqlalchemy import create_engine

db_url = 'mysql+pymysql://root:rootroot@localhost:3306/weather' 
engine = create_engine(db_url)

# %%
df.to_sql('weather', engine, if_exists='replace', index=False)
# Out:
# 242

# %%
engine.dispose()
